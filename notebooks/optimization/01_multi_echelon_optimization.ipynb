# %%
import pandas as pd

df = pd.read_csv("../../data/processed/optimized_inventory_plan.csv")

df.head(20)
# Out:
#      sku_id abc_class  location_id             echelon  \
# 0   SKU_001         A  FACTORY_001             factory
# 1   SKU_001         A       CW_001   central_warehouse
# 2   SKU_001         A       RW_001  regional_warehouse
# 3   SKU_001         A    STORE_001               store
# 4   SKU_002         A  FACTORY_001             factory
# 5   SKU_002         A       CW_001   central_warehouse
# 6   SKU_002         A       RW_001  regional_warehouse
# 7   SKU_002         A    STORE_001               store
# 8   SKU_003         B  FACTORY_001             factory
# 9   SKU_003         B       CW_001   central_warehouse
# 10  SKU_003         B       RW_001  regional_warehouse
# 11  SKU_003         B    STORE_001               store
# 12  SKU_004         A  FACTORY_001             factory
# 13  SKU_004         A       CW_001   central_warehouse
# 14  SKU_004         A       RW_001  regional_warehouse
# 15  SKU_004         A    STORE_001               store
# ...

# %%
df.groupby("echelon")["optimized_inventory_units"].sum()
# Out:
# echelon
# central_warehouse     14393.36
# factory               14393.36
# regional_warehouse    14393.36
# store                  3277.32
# Name: optimized_inventory_units, dtype: float64

# %%
df.groupby("abc_class")["optimized_inventory_units"].sum()
# Out:
# abc_class
# A    39910.63
# B     5516.04
# C     1030.73
# Name: optimized_inventory_units, dtype: float64
